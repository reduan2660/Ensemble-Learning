# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,precision_recall_fscore_support
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from xgboost import plot_importance
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pickle

# %% [markdown]
# ### Feature Reduction
#
# > https://github.com/avdhesh201/Intrusion-Detection-System/tree/main
#
# Tweaked codebase of mentioned repo
# > https://colab.research.google.com/drive/1mWcY6DGE9WnlUsxgYP6za7kGcf95RFzZ?usp=sharing

# %%
# Load the stored data
with open('./data/X_train_fr.pickle', 'rb') as f:
    X_train = pickle.load(f)

with open('./data/X_test_fr.pickle', 'rb') as f:
    X_test = pickle.load(f)

with open('./data/y_train_fr.pickle', 'rb') as f:
    y_train = pickle.load(f)

with open('./data/y_test_fr.pickle', 'rb') as f:
    y_test = pickle.load(f)

X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)

df = pd.read_csv("./data/CICIDS2017_fr.csv")
df.sample(2)
# Out:
#      Unnamed: 0  Init_Win_bytes_backward  min_seg_size_forward  Active Max  \
# 333         333                 0.007099                   0.0         0.0
# 1             1                 0.800006                   0.6         0.0
#
#      Max Packet Length  Init_Win_bytes_forward  Fwd Packet Length Max  \
# 333           0.000257                0.017227               0.000257
# 1             0.000000                0.445572               0.000000
#
#      Flow IAT Max  Total Length of Fwd Packets  Flow Duration  ...  \
# 333  2.881356e-07                     0.000002   2.833447e-07  ...
# 1    4.336431e-02                     0.000000   4.265071e-02  ...
#
#      Fwd Packet Length Min  Packet Length Std  Subflow Bwd Packets  \
# 333               0.004364                0.0             0.000181
# 1                 0.000000                0.0             0.000181
#
#      Avg Fwd Segment Size  Fwd PSH Flags  act_data_pkt_fwd  Fwd IAT Std  \
# 333               0.00101            0.0               0.0      0.00000
# 1                 0.00000            0.0               0.0      0.05715
#
#      Packet Length Variance  Fwd Packet Length Mean  Label
# 333                     0.0                 0.00101      1
# 1                       0.0                 0.00000      6
#
# [2 rows x 43 columns]

# %%
feature_names = df.columns[1:-1]

# %%
# Hash Partitionaing - With Poisoning - Robustness - Feature reducted data

def hash_partition_data(X, y, num_partitions=5, overlap=0, poison_fraction=0.1):
    pre_hash_data = X[:, :-1]
    idxgroup_final = []
    
    for time in range(overlap + 1):
        hash_data = [hash(str(row) + str(time)) % num_partitions for row in pre_hash_data]
        
        if time != overlap:
            idxgroup = [np.nonzero((hash_data == i))[0] for i in range(num_partitions)]
        else:
            idxgroup = [np.nonzero((hash_data == i))[0] for i in range(num_partitions - overlap * num_partitions)]
        
        idxgroup_final += idxgroup
    
    X_partitions = []
    y_partitions = []
    
    for i in range(num_partitions):
        idx_train = np.concatenate([idxgroup_final[j] for j in range(num_partitions) if j != i])
        idx_test = idxgroup_final[i]
        
        if len(idx_train) > 0 and len(idx_test) > 0:  # Check if partition has at least one sample
            X_train_partition, X_test_partition = X[idx_train], X[idx_test]
            y_train_partition, y_test_partition = y[idx_train], y[idx_test]
            
            # Introduce poison into the training data
            n_poison_samples = int(len(X_train_partition) * poison_fraction)
            poison_indices = np.random.choice(len(X_train_partition), n_poison_samples, replace=False)
            y_train_partition[poison_indices] = np.random.randint(0, np.max(y) + 1, size=n_poison_samples)
            
            X_partitions.append((X_train_partition, X_test_partition))
            y_partitions.append((y_train_partition, y_test_partition))
    
    return X_partitions, y_partitions


# Modified partition_data function
def partition_data(X, y, num_partitions=6, overlap=0, poison_fraction=0.1):
    if overlap > 0:
        return hash_partition_data(X, y, num_partitions, overlap, poison_fraction)
    else:
        X_partitions = []
        y_partitions = []
        
        for i in range(num_partitions):
            X_train_partition, X_test_partition, y_train_partition, y_test_partition = train_test_split(X, y, test_size=0.2, random_state=i)
            
            # Introduce poison into the training data
            n_poison_samples = int(len(X_train_partition) * poison_fraction)
            poison_indices = np.random.choice(len(X_train_partition), n_poison_samples, replace=False)
            y_train_partition[poison_indices] = np.random.randint(0, np.max(y) + 1, size=n_poison_samples)
            
            X_partitions.append((X_train_partition, X_test_partition))
            y_partitions.append((y_train_partition, y_test_partition))
        
        return X_partitions, y_partitions

# %%
# Feature importance or SHAP (SHapley Additive exPlanations).
def evaluate_ensemble(X_partitions, y_partitions, robustness_samples=100):
    ensemble_scores = []
    precision_scores = []
    recall_scores = []
    fscore_scores = []
    robustness_accuracies = []
    
    for i in range(len(X_partitions)):
        X_train, X_test = X_partitions[i]
        y_train, y_test = y_partitions[i]
        
        ensemble = DecisionTreeClassifier(random_state=0)
        ensemble.fit(X_train, y_train)
        ensemble_score = ensemble.score(X_test, y_test)
        y_predict = ensemble.predict(X_test)
        y_true = y_test
        
        ensemble_scores.append(ensemble_score)
        precision, recall, fscore, _ = precision_recall_fscore_support(y_true, y_predict, average='weighted')
        precision_scores.append(precision)
        recall_scores.append(recall)
        fscore_scores.append(fscore)
        
        # Evaluate robustness
        y_poison = np.random.randint(0, np.max(y_true) + 1, size=robustness_samples)
        y_predict_poison = ensemble.predict(X_test[:robustness_samples])
        
        accuracy_poison = accuracy_score(y_poison, y_predict_poison)
        robustness_accuracies.append(accuracy_poison)
        
        # Calculate feature importance
        feature_importance = ensemble.feature_importances_
        
        # Sort feature importance in descending order
        sorted_indices = np.argsort(feature_importance)[::-1]
        sorted_feature_names = [feature_names[i] for i in sorted_indices]
        sorted_importance = feature_importance[sorted_indices]

        # Print feature importance
        print("Feature Importance:")
        for feature_name, importance in zip(sorted_feature_names, sorted_importance):
            print(f"{feature_name}: {importance}")
        print()
    
    print('Average Accuracy of Ensemble: ' + str(np.mean(ensemble_scores)))
    print('Average Precision of Ensemble: ' + str(np.mean(precision_scores)))
    print('Average Recall of Ensemble: ' + str(np.mean(recall_scores)))
    print('Average F1-score of Ensemble: ' + str(np.mean(fscore_scores)))
    
    average_robustness = np.mean(robustness_accuracies)
    print('Average Robustness Accuracy: ' + str(average_robustness))

# %%
X_partitions, y_partitions = partition_data(X, y)
evaluate_ensemble(X_partitions, y_partitions)
# Out:
# Feature Importance:
# Init_Win_bytes_backward: 0.253338722650734
# Active Max: 0.1537901945447424
# min_seg_size_forward: 0.12508021800301988
# Flow IAT Max: 0.09134130613443636
# Bwd Packet Length Min: 0.04247315924294891
# Bwd IAT Mean: 0.04001696974800075
# Bwd Packets/s: 0.0396455386443121
# Avg Bwd Segment Size: 0.030145264725682016
# Init_Win_bytes_forward: 0.026286558382413998
# Fwd IAT Std: 0.015171772634014386
# Flow IAT Mean: 0.014300503225974303
# Flow IAT Std: 0.013931584345300183
# Fwd PSH Flags: 0.013912480745082218
# Fwd IAT Max: 0.01355077585354255
# Fwd IAT Total: 0.01314742821787908
# Fwd Header Length: 0.012535535778772915
# Packet Length Std: 0.012223870580429935
# Flow Duration: 0.012123919192075394
# Fwd IAT Min: 0.011239067480553942
# Max Packet Length: 0.009972196466179209
# Fwd Packet Length Max: 0.009371892880646182
# Packet Length Variance: 0.0066070618535190515
# Bwd Packet Length Max: 0.006150202350645474
# Fwd Packet Length Std: 0.005279473908480985
# Packet Length Mean: 0.0042701090196574105
# Bwd IAT Total: 0.004207373469965987
# Bwd Packet Length Std: 0.0025315838800718917
# Total Length of Fwd Packets: 0.0023510851166710337
# Avg Fwd Segment Size: 0.0023418913652867917
# Average Packet Size: 0.0022862611960134107
# act_data_pkt_fwd: 0.0017369292249692688
# Fwd Packet Length Mean: 0.001727893785951146
# Total Fwd Packets: 0.0016746984438586723
# Total Backward Packets: 0.001220799725681696
# Fwd Packet Length Min: 0.0008834318341122471
# Subflow Bwd Packets: 0.0006960699766074119
# Subflow Fwd Packets: 0.0006490893647789748
# Total Length of Bwd Packets: 0.0006444202815462036
# Bwd Packet Length Mean: 0.0005475326185034039
# PSH Flag Count: 0.00039168718663435786
# ACK Flag Count: 0.00020344592030385777
#
# Feature Importance:
# Init_Win_bytes_backward: 0.25837406553339815
# Active Max: 0.15098165603443928
# min_seg_size_forward: 0.11947998434613183
# Flow IAT Max: 0.09273659249144423
# Bwd Packets/s: 0.0442691254915834
# Bwd IAT Mean: 0.040531405356746354
# Bwd Packet Length Min: 0.038884284542605105
# Avg Bwd Segment Size: 0.038368929845098564
# Init_Win_bytes_forward: 0.027245722884852185
# Flow Duration: 0.015168292232178136
# Flow IAT Mean: 0.01354506484586371
# Fwd PSH Flags: 0.01349581669582603
# Fwd Packet Length Std: 0.01318277568434965
# Fwd IAT Total: 0.01237613950573652
# Fwd IAT Min: 0.01198546910735639
# Flow IAT Std: 0.01139153991564352
# Fwd IAT Std: 0.011127785817566195
# Bwd Packet Length Std: 0.01084094394698276
# Fwd Header Length: 0.010766233063757206
# Fwd IAT Max: 0.010515176177849146
# Avg Fwd Segment Size: 0.00938443599562261
# Bwd IAT Total: 0.007266991738892263
# Packet Length Std: 0.006519598371687434
# Packet Length Mean: 0.004115867923996468
# Packet Length Variance: 0.003802142522637274
# Total Length of Fwd Packets: 0.003533417180437297
# Fwd Packet Length Mean: 0.0030455834976666697
# Subflow Bwd Packets: 0.0028987235793727162
# Max Packet Length: 0.0019244914009637036
# Average Packet Size: 0.001924032282406644
# Subflow Fwd Packets: 0.0016854477310038166
# Total Length of Bwd Packets: 0.0016091855305953786
# Fwd Packet Length Max: 0.0016005853920689024
# Total Fwd Packets: 0.0014804001869983497
# Bwd Packet Length Mean: 0.0012444578431715326
# Total Backward Packets: 0.0011052192029482764
# Bwd Packet Length Max: 0.0009478259780793459
# Fwd Packet Length Min: 0.00023458809201370553
# ACK Flag Count: 0.00020500101501460827
# act_data_pkt_fwd: 0.00020500101501460827
# PSH Flag Count: 0.0
#
# Feature Importance:
# Init_Win_bytes_backward: 0.26439395492849793
# Active Max: 0.15269377878433762
# min_seg_size_forward: 0.11727248964272873
# Flow IAT Max: 0.08632484806940934
# Bwd Packets/s: 0.04418952570440816
# Avg Bwd Segment Size: 0.04407125912761813
# Bwd IAT Mean: 0.04132104066706766
# Bwd Packet Length Min: 0.030425545079071827
# Init_Win_bytes_forward: 0.030182651848546793
# Fwd IAT Total: 0.01940378712840609
# Flow Duration: 0.01625604568109564
# Fwd IAT Std: 0.015832941158746238
# Flow IAT Std: 0.014578559084218207
# Fwd PSH Flags: 0.013742835771210505
# Fwd IAT Max: 0.013474338698831642
# Fwd Header Length: 0.011435615131864401
# Fwd IAT Min: 0.009943889011396286
# Flow IAT Mean: 0.009842633598110866
# Bwd Packet Length Mean: 0.009836943108306566
# Bwd IAT Total: 0.00682227020492357
# Bwd Packet Length Std: 0.005675564193021561
# Packet Length Variance: 0.005508443349656184
# Average Packet Size: 0.004680776168685233
# Avg Fwd Segment Size: 0.00457172190239948
# Total Length of Fwd Packets: 0.004079618910283412
# Fwd Packet Length Max: 0.003214926483310152
# Packet Length Mean: 0.003104918860979309
# Fwd Packet Length Std: 0.002836817925649673
# Fwd Packet Length Mean: 0.0027641007191975225
# Subflow Bwd Packets: 0.0024466060016711767
# Packet Length Std: 0.002380641352911392
# Total Fwd Packets: 0.0012674141213629205
# Subflow Fwd Packets: 0.0012547518731394534
# Bwd Packet Length Max: 0.0009463652712218129
# act_data_pkt_fwd: 0.0009387156261038144
# Max Packet Length: 0.0008256678297024172
# Total Backward Packets: 0.000650277872794061
# Fwd Packet Length Min: 0.0005309660363208085
# Total Length of Bwd Packets: 0.00020891387946257432
# ACK Flag Count: 6.783919333102042e-05
# PSH Flag Count: 0.0
#
# Feature Importance:
# Init_Win_bytes_backward: 0.2294052939679471
# Active Max: 0.1609904721968306
# Flow IAT Max: 0.11975916796396165
# min_seg_size_forward: 0.11642702914067393
# Bwd Packets/s: 0.048141215225317176
# Fwd Packet Length Std: 0.0361596713173096
# Avg Bwd Segment Size: 0.03537003963926205
# Init_Win_bytes_forward: 0.027360406370469718
# Bwd Packet Length Min: 0.025535827153319708
# Flow Duration: 0.023359221011888236
# Flow IAT Std: 0.014827775329731506
# Fwd PSH Flags: 0.014024054949198103
# Average Packet Size: 0.013918200431060821
# Fwd IAT Max: 0.013831776939754663
# Fwd IAT Std: 0.013804555024960176
# Fwd IAT Total: 0.013382210444510016
# Packet Length Std: 0.012948926040290716
# Fwd Header Length: 0.012643572580626268
# Flow IAT Mean: 0.010729600907950547
# Fwd IAT Min: 0.008894543064161872
# Bwd IAT Mean: 0.0068345330404853254
# Bwd IAT Total: 0.004974968564449836
# Bwd Packet Length Mean: 0.004581784150983778
# Avg Fwd Segment Size: 0.0038935681098467025
# Fwd Packet Length Max: 0.0029905628992022495
# Fwd Packet Length Mean: 0.0027016970068110225
# Packet Length Mean: 0.002693105953466186
# Packet Length Variance: 0.002587930355418862
# Total Length of Fwd Packets: 0.0025712324081470198
# Max Packet Length: 0.0020854183787966615
# Bwd Packet Length Std: 0.0019026896573064189
# Bwd Packet Length Max: 0.0017993221419490136
# Subflow Fwd Packets: 0.001504317703913523
# Total Backward Packets: 0.0014453120268242896
# Total Fwd Packets: 0.0012977904218682435
# PSH Flag Count: 0.0010137850706924308
# Subflow Bwd Packets: 0.0010090370071436415
# ACK Flag Count: 0.0009340079549324001
# act_data_pkt_fwd: 0.0007626091154539114
# Total Length of Bwd Packets: 0.000698686426624885
# Fwd Packet Length Min: 0.00020408190645924542
#
# Feature Importance:
# Init_Win_bytes_backward: 0.2394614237718512
# Active Max: 0.15864753053712166
# min_seg_size_forward: 0.12124713607261982
# Flow IAT Max: 0.0892922850013784
# Bwd Packets/s: 0.04820763550525059
# Flow IAT Mean: 0.047648506245997965
# Fwd Packet Length Std: 0.03715847122096915
# Avg Bwd Segment Size: 0.027955135933860127
# Bwd Packet Length Min: 0.026781436701161912
# Init_Win_bytes_forward: 0.022688051103258253
# Fwd IAT Std: 0.015766799591848343
# Flow Duration: 0.015405986329798432
# Flow IAT Std: 0.015274183054243858
# Fwd IAT Total: 0.01524002674566625
# Fwd IAT Max: 0.01371584375274233
# Total Length of Fwd Packets: 0.012781194830138943
# Fwd PSH Flags: 0.012001228750000594
# Average Packet Size: 0.010879880508471343
# Packet Length Variance: 0.009131433300377856
# Fwd IAT Min: 0.006871105403428613
# Bwd IAT Total: 0.006846130923147784
# Fwd Packet Length Max: 0.005733824814481158
# Bwd Packet Length Max: 0.005686429380221293
# Bwd Packet Length Mean: 0.005251659761651553
# Packet Length Std: 0.0045742769982661
# Packet Length Mean: 0.0036299365066266853
# Bwd IAT Mean: 0.0033545014402091475
# Avg Fwd Segment Size: 0.0022864112052753288
# Fwd Header Length: 0.002139849186419492
# Subflow Bwd Packets: 0.0021162252708102555
# act_data_pkt_fwd: 0.001994582548118316
# Total Length of Bwd Packets: 0.001965545550471853
# Bwd Packet Length Std: 0.001929846721511985
# Fwd Packet Length Mean: 0.001596530539286896
# Max Packet Length: 0.0013211071029614945
# Total Backward Packets: 0.0008815823923013649
# Fwd Packet Length Min: 0.0007181979063118387
# PSH Flag Count: 0.0006159978757145001
# Subflow Fwd Packets: 0.0004661075990413555
# Total Fwd Packets: 0.0004362696736177184
# ACK Flag Count: 0.0002996922433682977
#
# Feature Importance:
# Init_Win_bytes_backward: 0.24736670473861927
# Active Max: 0.15867691477135046
# min_seg_size_forward: 0.12169121982843209
# Flow IAT Max: 0.08912879087778243
# Bwd IAT Mean: 0.045511370490172134
# Bwd Packets/s: 0.038542511293412775
# Bwd Packet Length Min: 0.03852716027636427
# Avg Bwd Segment Size: 0.03056854097068715
# Init_Win_bytes_forward: 0.02845986510262818
# Flow IAT Std: 0.016818446962285922
# Flow Duration: 0.016086402945678223
# Fwd IAT Max: 0.014280538948517328
# Fwd Packet Length Mean: 0.0139554960146474
# Fwd PSH Flags: 0.013639087463800386
# Fwd IAT Std: 0.01342853996089064
# Fwd IAT Total: 0.011527537737516686
# Fwd IAT Min: 0.011188763081823068
# Average Packet Size: 0.01111042824145771
# Fwd Header Length: 0.010158432567324306
# Flow IAT Mean: 0.010020132733941482
# Bwd Packet Length Std: 0.00903058864253806
# Packet Length Mean: 0.006279982982921369
# Bwd Packet Length Mean: 0.005999656305460036
# Bwd IAT Total: 0.005379579699296767
# Packet Length Std: 0.005013129827406349
# Total Length of Fwd Packets: 0.004087502089442583
# Fwd Packet Length Std: 0.0037465120907654147
# Fwd Packet Length Max: 0.0031575341992784813
# Max Packet Length: 0.0026206234634946245
# Packet Length Variance: 0.0023231618798846628
# Bwd Packet Length Max: 0.0019498551825438998
# Subflow Bwd Packets: 0.0015943817268532655
# Subflow Fwd Packets: 0.0013995982440089677
# Avg Fwd Segment Size: 0.0013851161613672865
# act_data_pkt_fwd: 0.0011825748327012702
# Total Fwd Packets: 0.0010223516416463685
# Total Length of Bwd Packets: 0.000913263247927996
# Total Backward Packets: 0.000751518754099636
# Fwd Packet Length Min: 0.0006242243196590805
# ACK Flag Count: 0.0005452542088780632
# PSH Flag Count: 0.00030670549249391056
#
# Average Accuracy of Ensemble: 0.9110468850353244
# Average Precision of Ensemble: 0.9174188005455371
# Average Recall of Ensemble: 0.9110468850353244
# Average F1-score of Ensemble: 0.912840581583472
# Average Robustness Accuracy: 0.14333333333333334
