# %%
import numpy as np
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import precision_score, recall_score, f1_score, hamming_loss, precision_recall_fscore_support, accuracy_score
from sklearn.ensemble import VotingClassifier

# %%
# Load the stored partitions

with open('./data/X_train_sample.pickle', 'rb') as f:
    X_train = pickle.load(f)

with open('./data/X_test_sample.pickle', 'rb') as f:
    X_test = pickle.load(f)

with open('./data/y_train_sample.pickle', 'rb') as f:
    y_train = pickle.load(f)

with open('./data/y_test_sample.pickle', 'rb') as f:
    y_test = pickle.load(f)

X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)

# %%
# Hash partitioning - Without Poisoning

def hash_partition_data(X, y, num_partitions=5, overlap=0):
    pre_hash_data = X[:, :-1]
    idxgroup_final = []
    
    for time in range(overlap + 1):
        hash_data = [hash(str(row) + str(time)) % num_partitions for row in pre_hash_data]
        
        if time != overlap:
            idxgroup = [np.nonzero((hash_data == i))[0] for i in range(num_partitions)]
        else:
            idxgroup = [np.nonzero((hash_data == i))[0] for i in range(num_partitions - overlap * num_partitions)]
        
        idxgroup_final += idxgroup
    
    X_partitions = []
    y_partitions = []
    
    for i in range(num_partitions):
        idx_train = np.concatenate([idxgroup_final[j] for j in range(num_partitions) if j != i])
        idx_test = idxgroup_final[i]
        X_train_partition, X_test_partition = X[idx_train], X[idx_test]
        y_train_partition, y_test_partition = y[idx_train], y[idx_test]
        
        X_partitions.append((X_train_partition, X_test_partition))
        y_partitions.append((y_train_partition, y_test_partition))
    
    return X_partitions, y_partitions

# Modified partition_data function
def partition_data(X, y, num_partitions=5, overlap=0):
    if overlap > 0:
        return hash_partition_data(X, y, num_partitions, overlap)
    else:
        X_partitions = []
        y_partitions = []
        
        for i in range(num_partitions):
            X_train_partition, X_test_partition, y_train_partition, y_test_partition = train_test_split(X, y, test_size=0.2, random_state=i)
            X_partitions.append((X_train_partition, X_test_partition))
            y_partitions.append((y_train_partition, y_test_partition))
        
        return X_partitions, y_partitions

def evaluate_ensemble(X_train, y_train, X_test, y_test):
    ensemble = VotingClassifier(estimators=[('dt{}'.format(i), DecisionTreeClassifier(random_state=0)) for i in range(5)], voting='hard')
    
    ensemble.fit(X_train, y_train)
    ensemble_score = ensemble.score(X_test, y_test)
    y_predict = ensemble.predict(X_test)
    y_true = y_test
    
    print('Accuracy of Ensemble: ' + str(ensemble_score))
    precision, recall, fscore, none = precision_recall_fscore_support(y_true, y_predict, average='weighted')
    print('Precision of Ensemble: ' + str(precision))
    print('Recall of Ensemble: ' + str(recall))
    print('F1-score of Ensemble: ' + str(fscore))

# Example usage
X_partitions, y_partitions = partition_data(X, y)
X_train, X_test = X_partitions[0]
y_train, y_test = y_partitions[0]
evaluate_ensemble(X_train, y_train, X_test, y_test)
# Out:
# Accuracy of Ensemble: 0.9890815671162492
# Precision of Ensemble: 0.9887818547656925
# Recall of Ensemble: 0.9890815671162492
# F1-score of Ensemble: 0.9886774566843135

# %%
# Hash partitioning - With Poisoning

def hash_partition_data(X, y, num_partitions=5, overlap=0, poison_fraction=0.1):
    pre_hash_data = X[:, :-1]
    idxgroup_final = []
    
    for time in range(overlap + 1):
        hash_data = [hash(str(row) + str(time)) % num_partitions for row in pre_hash_data]
        
        if time != overlap:
            idxgroup = [np.nonzero((hash_data == i))[0] for i in range(num_partitions)]
        else:
            idxgroup = [np.nonzero((hash_data == i))[0] for i in range(num_partitions - overlap * num_partitions)]
        
        idxgroup_final += idxgroup
    
    X_partitions = []
    y_partitions = []
    
    for i in range(num_partitions):
        idx_train = np.concatenate([idxgroup_final[j] for j in range(num_partitions) if j != i])
        idx_test = idxgroup_final[i]
        X_train_partition, X_test_partition = X[idx_train], X[idx_test]
        y_train_partition, y_test_partition = y[idx_train], y[idx_test]
        
        # Introduce poison into the training data
        n_poison_samples = int(len(X_train_partition) * poison_fraction)
        poison_indices = np.random.choice(len(X_train_partition), n_poison_samples, replace=False)
        y_train_partition[poison_indices] = np.random.randint(0, np.max(y) + 1, size=n_poison_samples)
        
        X_partitions.append((X_train_partition, X_test_partition))
        y_partitions.append((y_train_partition, y_test_partition))
    
    return X_partitions, y_partitions

# Modified partition_data function
def partition_data(X, y, num_partitions=6, overlap=0, poison_fraction=0.1):
    if overlap > 0:
        return hash_partition_data(X, y, num_partitions, overlap, poison_fraction)
    else:
        X_partitions = []
        y_partitions = []
        
        for i in range(num_partitions):
            X_train_partition, X_test_partition, y_train_partition, y_test_partition = train_test_split(X, y, test_size=0.2, random_state=i)
            
            # Introduce poison into the training data
            n_poison_samples = int(len(X_train_partition) * poison_fraction)
            poison_indices = np.random.choice(len(X_train_partition), n_poison_samples, replace=False)
            y_train_partition[poison_indices] = np.random.randint(0, np.max(y) + 1, size=n_poison_samples)
            
            X_partitions.append((X_train_partition, X_test_partition))
            y_partitions.append((y_train_partition, y_test_partition))
        
        return X_partitions, y_partitions

def evaluate_ensemble(X_train, y_train, X_test, y_test):
    ensemble = VotingClassifier(estimators=[('dt{}'.format(i), DecisionTreeClassifier(random_state=0)) for i in range(5)], voting='hard')
    
    ensemble.fit(X_train, y_train)
    ensemble_score = ensemble.score(X_test, y_test)
    y_predict = ensemble.predict(X_test)
    y_true = y_test
    
    print('Accuracy of Ensemble: ' + str(ensemble_score))
    precision, recall, fscore, none = precision_recall_fscore_support(y_true, y_predict, average='weighted')
    print('Precision of Ensemble: ' + str(precision))
    print('Recall of Ensemble: ' + str(recall))
    print('F1-score of Ensemble: ' + str(fscore))


X_partitions, y_partitions = partition_data(X, y)
X_train, X_test = X_partitions[0]
y_train, y_test = y_partitions[0]
evaluate_ensemble(X_train, y_train, X_test, y_test)
# Out:
# Accuracy of Ensemble: 0.9094412331406551
# Precision of Ensemble: 0.9133893283915164
# Recall of Ensemble: 0.9094412331406551
# F1-score of Ensemble: 0.9101690966140465

# %%
# Hash Partitionaing - With Poisoning - Robustness

def hash_partition_data(X, y, num_partitions=5, overlap=0, poison_fraction=0.1):
    pre_hash_data = X[:, :-1]
    idxgroup_final = []
    
    for time in range(overlap + 1):
        hash_data = [hash(str(row) + str(time)) % num_partitions for row in pre_hash_data]
        
        if time != overlap:
            idxgroup = [np.nonzero((hash_data == i))[0] for i in range(num_partitions)]
        else:
            idxgroup = [np.nonzero((hash_data == i))[0] for i in range(num_partitions - overlap * num_partitions)]
        
        idxgroup_final += idxgroup
    
    X_partitions = []
    y_partitions = []
    
    for i in range(num_partitions):
        idx_train = np.concatenate([idxgroup_final[j] for j in range(num_partitions) if j != i])
        idx_test = idxgroup_final[i]
        
        if len(idx_train) > 0 and len(idx_test) > 0:  # Check if partition has at least one sample
            X_train_partition, X_test_partition = X[idx_train], X[idx_test]
            y_train_partition, y_test_partition = y[idx_train], y[idx_test]
            
            # Introduce poison into the training data
            n_poison_samples = int(len(X_train_partition) * poison_fraction)
            poison_indices = np.random.choice(len(X_train_partition), n_poison_samples, replace=False)
            y_train_partition[poison_indices] = np.random.randint(0, np.max(y) + 1, size=n_poison_samples)
            
            X_partitions.append((X_train_partition, X_test_partition))
            y_partitions.append((y_train_partition, y_test_partition))
    
    return X_partitions, y_partitions


# Modified partition_data function
def partition_data(X, y, num_partitions=6, overlap=0, poison_fraction=0.1):
    if overlap > 0:
        return hash_partition_data(X, y, num_partitions, overlap, poison_fraction)
    else:
        X_partitions = []
        y_partitions = []
        
        for i in range(num_partitions):
            X_train_partition, X_test_partition, y_train_partition, y_test_partition = train_test_split(X, y, test_size=0.2, random_state=i)
            
            # Introduce poison into the training data
            n_poison_samples = int(len(X_train_partition) * poison_fraction)
            poison_indices = np.random.choice(len(X_train_partition), n_poison_samples, replace=False)
            y_train_partition[poison_indices] = np.random.randint(0, np.max(y) + 1, size=n_poison_samples)
            
            X_partitions.append((X_train_partition, X_test_partition))
            y_partitions.append((y_train_partition, y_test_partition))
        
        return X_partitions, y_partitions
    

def evaluate_ensemble(X_partitions, y_partitions, robustness_samples=100):
    ensemble_scores = []
    precision_scores = []
    recall_scores = []
    fscore_scores = []
    robustness_accuracies = []
    
    for i in range(len(X_partitions)):
        X_train, X_test = X_partitions[i]
        y_train, y_test = y_partitions[i]
        
        ensemble = DecisionTreeClassifier(random_state=0)
        ensemble.fit(X_train, y_train)
        ensemble_score = ensemble.score(X_test, y_test)
        y_predict = ensemble.predict(X_test)
        y_true = y_test
        
        ensemble_scores.append(ensemble_score)
        precision, recall, fscore, _ = precision_recall_fscore_support(y_true, y_predict, average='weighted')
        precision_scores.append(precision)
        recall_scores.append(recall)
        fscore_scores.append(fscore)
        
        # Evaluate robustness
        y_poison = np.random.randint(0, np.max(y_true) + 1, size=robustness_samples)
        y_predict_poison = ensemble.predict(X_test[:robustness_samples])
        
        accuracy_poison = accuracy_score(y_poison, y_predict_poison)
        robustness_accuracies.append(accuracy_poison)
    
    print('Average Accuracy of Ensemble: ' + str(np.mean(ensemble_scores)))
    print('Average Precision of Ensemble: ' + str(np.mean(precision_scores)))
    print('Average Recall of Ensemble: ' + str(np.mean(recall_scores)))
    print('Average F1-score of Ensemble: ' + str(np.mean(fscore_scores)))
    
    average_robustness = np.mean(robustness_accuracies)
    print('Average Robustness Accuracy: ' + str(average_robustness))
# Example usage
X_partitions, y_partitions = partition_data(X, y)
evaluate_ensemble(X_partitions, y_partitions)
# Out:
# Average Accuracy of Ensemble: 0.8993791479340612
# Average Precision of Ensemble: 0.9064609329828576
# Average Recall of Ensemble: 0.8993791479340612
# Average F1-score of Ensemble: 0.9013824933713938
# Average Robustness Accuracy: 0.13833333333333334

# %%
# Feature importance or SHAP (SHapley Additive exPlanations).

def evaluate_ensemble(X_partitions, y_partitions, robustness_samples=100):
    ensemble_scores = []
    precision_scores = []
    recall_scores = []
    fscore_scores = []
    robustness_accuracies = []
    
    for i in range(len(X_partitions)):
        X_train, X_test = X_partitions[i]
        y_train, y_test = y_partitions[i]
        
        ensemble = DecisionTreeClassifier(random_state=0)
        ensemble.fit(X_train, y_train)
        ensemble_score = ensemble.score(X_test, y_test)
        y_predict = ensemble.predict(X_test)
        y_true = y_test
        
        ensemble_scores.append(ensemble_score)
        precision, recall, fscore, _ = precision_recall_fscore_support(y_true, y_predict, average='weighted')
        precision_scores.append(precision)
        recall_scores.append(recall)
        fscore_scores.append(fscore)
        
        # Evaluate robustness
        y_poison = np.random.randint(0, np.max(y_true) + 1, size=robustness_samples)
        y_predict_poison = ensemble.predict(X_test[:robustness_samples])
        
        accuracy_poison = accuracy_score(y_poison, y_predict_poison)
        robustness_accuracies.append(accuracy_poison)
        
        # Calculate feature importance
        feature_importance = ensemble.feature_importances_
        # You can then use the feature_importance to understand the importance of each feature in the poison injection
        
        # Print feature importance
        feature_names = ['Flow Duration', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets',
                         'Total Length of Bwd Packets', 'Fwd Packet Length Max', 'Fwd Packet Length Min',
                         'Fwd Packet Length Mean', 'Fwd Packet Length Std', 'Bwd Packet Length Max',
                         'Bwd Packet Length Min', 'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s',
                         'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
                         'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min',
                         'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min',
                         'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
                         'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s', 'Min Packet Length',
                         'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Packet Length Variance',
                         'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
                         'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio', 'Average Packet Size',
                         'Avg Fwd Segment Size', 'Avg Bwd Segment Size', 'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk',
                         'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
                         'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes', 'Subflow Bwd Packets',
                         'Subflow Bwd Bytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward',
                         'act_data_pkt_fwd', 'min_seg_size_forward', 'Active Mean', 'Active Std', 'Active Max',
                         'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min']
        
        print("Feature Importance:")
        for feature_name, importance in zip(feature_names, feature_importance):
            print(f"{feature_name}: {importance}")
        print()
    
    print('Average Accuracy of Ensemble: ' + str(np.mean(ensemble_scores)))
    print('Average Precision of Ensemble: ' + str(np.mean(precision_scores)))
    print('Average Recall of Ensemble: ' + str(np.mean(recall_scores)))
    print('Average F1-score of Ensemble: ' + str(np.mean(fscore_scores)))
    
    average_robustness = np.mean(robustness_accuracies)
    print('Average Robustness Accuracy: ' + str(average_robustness))
    


# Example usage
X_partitions, y_partitions = partition_data(X, y, num_partitions=5, overlap=0, poison_fraction=0.1)
evaluate_ensemble(X_partitions, y_partitions, robustness_samples=100)
# Out:
# Feature Importance:
# Flow Duration: 0.012533049981794216
# Total Fwd Packets: 0.0010891130327247613
# Total Backward Packets: 0.0015632199054369123
# Total Length of Fwd Packets: 0.015362770986320391
# Total Length of Bwd Packets: 0.0009927470105751672
# Fwd Packet Length Max: 0.004970783786611444
# Fwd Packet Length Min: 0.0
# Fwd Packet Length Mean: 0.0015000378345169604
# Fwd Packet Length Std: 0.024467564007137302
# Bwd Packet Length Max: 0.0013733988287559736
# Bwd Packet Length Min: 0.029543211286770777
# Bwd Packet Length Mean: 0.006170265643870845
# Bwd Packet Length Std: 0.002786740165343103
# Flow Bytes/s: 0.0
# Flow Packets/s: 0.0
# Flow IAT Mean: 0.009358270472229544
# Flow IAT Std: 0.011252478290639262
# Flow IAT Max: 0.08728042208632827
# Flow IAT Min: 0.007023451743281711
# Fwd IAT Total: 0.011433278080338406
# Fwd IAT Mean: 0.010718294794671589
# Fwd IAT Std: 0.009253942551333572
# Fwd IAT Max: 0.024800269184060683
# Fwd IAT Min: 0.04442926097830635
# Bwd IAT Total: 0.003999199283439806
# Bwd IAT Mean: 0.004770205794261309
# Bwd IAT Std: 0.004354794701330792
# Bwd IAT Max: 0.005856380029998593
# Bwd IAT Min: 0.0034601169311224093
# Fwd PSH Flags: 0.0011461178646495318
# Bwd PSH Flags: 0.0
# Fwd URG Flags: 0.0
# Bwd URG Flags: 0.0
# Fwd Header Length: 0.0028890818237744375
# Bwd Header Length: 0.0019488345807089243
# Fwd Packets/s: 0.008471503563792173
# Bwd Packets/s: 0.03883108159515457
# Min Packet Length: 0.00027705155339296177
# Max Packet Length: 0.0016034407866930467
# Packet Length Mean: 0.006196140747325226
# Packet Length Std: 0.0014696911921273448
# Packet Length Variance: 0.0035506520035521213
# FIN Flag Count: 0.0
# SYN Flag Count: 0.0
# RST Flag Count: 0.0
# PSH Flag Count: 0.0
# ACK Flag Count: 0.0003011874583766231
# URG Flag Count: 0.0005472976155977991
# CWE Flag Count: 0.0
# ECE Flag Count: 0.0
# Down/Up Ratio: 0.0007130319048563043
# Average Packet Size: 0.008535052186502554
# Avg Fwd Segment Size: 0.0019319588911855842
# Avg Bwd Segment Size: 0.011975395018332908
# Fwd Header Length.1: 0.0005791110328622462
# Fwd Avg Bytes/Bulk: 0.0
# Fwd Avg Packets/Bulk: 0.0
# Fwd Avg Bulk Rate: 0.0
# Bwd Avg Bytes/Bulk: 0.0
# Bwd Avg Packets/Bulk: 0.0
# Bwd Avg Bulk Rate: 0.0
# Subflow Fwd Packets: 0.000691087696103519
# Subflow Fwd Bytes: 0.006345556848940579
# Subflow Bwd Packets: 0.0005234184120950328
# Subflow Bwd Bytes: 0.001864895942648108
# Init_Win_bytes_forward: 0.04254117844073458
# Init_Win_bytes_backward: 0.2402207301375035
# act_data_pkt_fwd: 0.0009832454839953238
# min_seg_size_forward: 0.114238827179392
# Active Mean: 0.00045800824086003085
# Active Std: 0.0013152661992817856
# Active Max: 0.14972738788467477
# Active Min: 0.002166055994841854
# Idle Mean: 0.0020677241050872973
# Idle Std: 0.00163741983322334
# Idle Max: 0.00048519793914180597
# Idle Min: 0.003424102451391878
#
# Feature Importance:
# Flow Duration: 0.024248062750225504
# Total Fwd Packets: 0.0005705781101069509
# Total Backward Packets: 0.0007132226376336885
# Total Length of Fwd Packets: 0.0013042067374744472
# Total Length of Bwd Packets: 0.0007567543216035456
# Fwd Packet Length Max: 0.0032052045928133307
# Fwd Packet Length Min: 0.0
# Fwd Packet Length Mean: 0.001046027330147956
# Fwd Packet Length Std: 0.04662524782122963
# Bwd Packet Length Max: 0.0007913129346696097
# Bwd Packet Length Min: 0.026912441180853144
# Bwd Packet Length Mean: 0.01156013715533692
# Bwd Packet Length Std: 0.0008405346415343264
# Flow Bytes/s: 0.0
# Flow Packets/s: 0.0
# Flow IAT Mean: 0.010400094923852085
# Flow IAT Std: 0.0142073834632647
# Flow IAT Max: 0.0920831917187883
# Flow IAT Min: 0.006658932929769579
# Fwd IAT Total: 0.00986908937177507
# Fwd IAT Mean: 0.04403860318591323
# Fwd IAT Std: 0.011084412822002244
# Fwd IAT Max: 0.01500609679442022
# Fwd IAT Min: 0.01158501152599547
# Bwd IAT Total: 0.0035654039852424575
# Bwd IAT Mean: 0.00577822176131932
# Bwd IAT Std: 0.0020632135413327013
# Bwd IAT Max: 0.003715994584198704
# Bwd IAT Min: 0.004730584913338473
# Fwd PSH Flags: 0.00027170386195569083
# Bwd PSH Flags: 0.0
# Fwd URG Flags: 0.0
# Bwd URG Flags: 0.0
# Fwd Header Length: 0.0005931211232329931
# Bwd Header Length: 0.0004794118564801224
# Fwd Packets/s: 0.007881414762124827
# Bwd Packets/s: 0.025561910040449
# Min Packet Length: 0.000916813622893967
# Max Packet Length: 0.005596347520047
# Packet Length Mean: 0.001271266740660588
# Packet Length Std: 0.002977752581932262
# Packet Length Variance: 0.023716384887062895
# FIN Flag Count: 0.00027170386195569083
# SYN Flag Count: 0.0
# RST Flag Count: 0.0
# PSH Flag Count: 0.0
# ACK Flag Count: 0.0005058486606410362
# URG Flag Count: 0.0009311151579359507
# CWE Flag Count: 0.0
# ECE Flag Count: 0.0
# Down/Up Ratio: 0.00013127738513756215
# Average Packet Size: 0.002966458667410551
# Avg Fwd Segment Size: 0.002079343314890739
# Avg Bwd Segment Size: 0.01999943754978487
# Fwd Header Length.1: 0.0005434077239113817
# Fwd Avg Bytes/Bulk: 0.0
# Fwd Avg Packets/Bulk: 0.0
# Fwd Avg Bulk Rate: 0.0
# Bwd Avg Bytes/Bulk: 0.0
# Bwd Avg Packets/Bulk: 0.0
# Bwd Avg Bulk Rate: 0.0
# Subflow Fwd Packets: 0.010993871737069952
# Subflow Fwd Bytes: 0.008429119173924785
# Subflow Bwd Packets: 0.0004754817584224589
# Subflow Bwd Bytes: 0.001191335539745145
# Init_Win_bytes_forward: 0.021715705508104317
# Init_Win_bytes_backward: 0.22594646981053917
# act_data_pkt_fwd: 0.00042165875064265393
# min_seg_size_forward: 0.11643068171183252
# Active Mean: 0.0019106341612611917
# Active Std: 0.0006917652346123763
# Active Max: 0.1525366612184535
# Active Min: 0.0017129227839768589
# Idle Mean: 0.0021394810457591416
# Idle Std: 0.001694292471938995
# Idle Max: 0.00132939465737818
# Idle Min: 0.002325839382990096
#
# Feature Importance:
# Flow Duration: 0.0089341546759592
# Total Fwd Packets: 0.000646364642561899
# Total Backward Packets: 0.0010829971079975513
# Total Length of Fwd Packets: 0.020877106893766484
# Total Length of Bwd Packets: 0.000640498152308357
# Fwd Packet Length Max: 0.0028252547064421506
# Fwd Packet Length Min: 0.0
# Fwd Packet Length Mean: 0.0019174625491176986
# Fwd Packet Length Std: 0.025452956048054063
# Bwd Packet Length Max: 0.00026968343255088714
# Bwd Packet Length Min: 0.030189903487123824
# Bwd Packet Length Mean: 0.021824484977568132
# Bwd Packet Length Std: 0.00038537584984461496
# Flow Bytes/s: 0.0
# Flow Packets/s: 0.0
# Flow IAT Mean: 0.045709350113924734
# Flow IAT Std: 0.014129342119686975
# Flow IAT Max: 0.09409339401294572
# Flow IAT Min: 0.006598508605285629
# Fwd IAT Total: 0.010594484953698047
# Fwd IAT Mean: 0.008289059275925811
# Fwd IAT Std: 0.006841321091695082
# Fwd IAT Max: 0.017400443049538743
# Fwd IAT Min: 0.010125712744619503
# Bwd IAT Total: 0.004984819323549077
# Bwd IAT Mean: 0.005371997696567068
# Bwd IAT Std: 0.00580607117337456
# Bwd IAT Max: 0.004045855149762799
# Bwd IAT Min: 0.004533714570864739
# Fwd PSH Flags: 0.0
# Bwd PSH Flags: 0.0
# Fwd URG Flags: 0.0
# Bwd URG Flags: 0.0
# Fwd Header Length: 0.001473595222696806
# Bwd Header Length: 0.00027052962006288866
# Fwd Packets/s: 0.012864596669061427
# Bwd Packets/s: 0.03558975791307996
# Min Packet Length: 0.0004854301785915968
# Max Packet Length: 0.002736652212056892
# Packet Length Mean: 0.0029049969532041237
# Packet Length Std: 0.002608314827640513
# Packet Length Variance: 0.0012529291130003804
# FIN Flag Count: 0.0
# SYN Flag Count: 0.00042699876820557125
# RST Flag Count: 0.0
# PSH Flag Count: 0.00020226257441316534
# ACK Flag Count: 0.0007247742249805091
# URG Flag Count: 0.00033914734699581255
# CWE Flag Count: 0.0
# ECE Flag Count: 0.0
# Down/Up Ratio: 0.00047574390950676384
# Average Packet Size: 0.013157511970076141
# Avg Fwd Segment Size: 0.0008629512171293436
# Avg Bwd Segment Size: 0.010779009056815576
# Fwd Header Length.1: 0.001681567448228953
# Fwd Avg Bytes/Bulk: 0.0
# Fwd Avg Packets/Bulk: 0.0
# Fwd Avg Bulk Rate: 0.0
# Bwd Avg Bytes/Bulk: 0.0
# Bwd Avg Packets/Bulk: 0.0
# Bwd Avg Bulk Rate: 0.0
# Subflow Fwd Packets: 0.0015755758375968116
# Subflow Fwd Bytes: 0.002296234758333498
# Subflow Bwd Packets: 0.0003593940259641263
# Subflow Bwd Bytes: 0.003940080580115017
# Init_Win_bytes_forward: 0.030568866896076928
# Init_Win_bytes_backward: 0.24196970218951952
# act_data_pkt_fwd: 0.0005008406604516476
# min_seg_size_forward: 0.11586311319611876
# Active Mean: 0.0009845960846598366
# Active Std: 0.0006835148332762258
# Active Max: 0.15254897611628826
# Active Min: 0.002505159442813828
# Idle Mean: 0.001247663313336544
# Idle Std: 0.00047194600696405243
# Idle Max: 0.0007183295841291093
# Idle Min: 0.0013589208438759069
#
# Feature Importance:
# Flow Duration: 0.007755821166463513
# Total Fwd Packets: 0.0004442277275463749
# Total Backward Packets: 0.0019119063515819767
# Total Length of Fwd Packets: 0.012082074984442233
# Total Length of Bwd Packets: 0.000657559575287327
# Fwd Packet Length Max: 0.00037519018339047047
# Fwd Packet Length Min: 0.00039642347601054134
# Fwd Packet Length Mean: 0.001848858172846841
# Fwd Packet Length Std: 0.03755720333314571
# Bwd Packet Length Max: 0.0011109685403665947
# Bwd Packet Length Min: 0.0283213450627284
# Bwd Packet Length Mean: 0.0014292344075872395
# Bwd Packet Length Std: 0.0011704962075060115
# Flow Bytes/s: 0.0
# Flow Packets/s: 0.0
# Flow IAT Mean: 0.008451746063816266
# Flow IAT Std: 0.014754867515307765
# Flow IAT Max: 0.09281652711479363
# Flow IAT Min: 0.003620782829534994
# Fwd IAT Total: 0.011692696408515092
# Fwd IAT Mean: 0.04241487559760955
# Fwd IAT Std: 0.011022677618407218
# Fwd IAT Max: 0.012522123861239095
# Fwd IAT Min: 0.008476283125563694
# Bwd IAT Total: 0.0059639357987871545
# Bwd IAT Mean: 0.0036749033105838718
# Bwd IAT Std: 0.004093322339649389
# Bwd IAT Max: 0.0034780646630617144
# Bwd IAT Min: 0.0053037735518258015
# Fwd PSH Flags: 0.0
# Bwd PSH Flags: 0.0
# Fwd URG Flags: 0.0
# Bwd URG Flags: 0.0
# Fwd Header Length: 0.0017559960829516903
# Bwd Header Length: 0.0014203538490946389
# Fwd Packets/s: 0.011563353861465123
# Bwd Packets/s: 0.035949270600580424
# Min Packet Length: 0.00035921192920520645
# Max Packet Length: 0.0007464189773531819
# Packet Length Mean: 0.0009120597472989706
# Packet Length Std: 0.0027586806342214483
# Packet Length Variance: 0.00228342353811555
# FIN Flag Count: 0.0
# SYN Flag Count: 0.0
# RST Flag Count: 0.0
# PSH Flag Count: 0.00043151342114137884
# ACK Flag Count: 0.0
# URG Flag Count: 0.0032193319180218076
# CWE Flag Count: 0.0
# ECE Flag Count: 0.0
# Down/Up Ratio: 0.0011552192386597405
# Average Packet Size: 0.01231296867093673
# Avg Fwd Segment Size: 0.0030782402804955056
# Avg Bwd Segment Size: 0.03326990427095922
# Fwd Header Length.1: 0.00031770110187736086
# Fwd Avg Bytes/Bulk: 0.0
# Fwd Avg Packets/Bulk: 0.0
# Fwd Avg Bulk Rate: 0.0
# Bwd Avg Bytes/Bulk: 0.0
# Bwd Avg Packets/Bulk: 0.0
# Bwd Avg Bulk Rate: 0.0
# Subflow Fwd Packets: 0.009525189858792438
# Subflow Fwd Bytes: 0.0006099447372771467
# Subflow Bwd Packets: 0.0008868814576369177
# Subflow Bwd Bytes: 0.0007607371536382635
# Init_Win_bytes_forward: 0.04976213937580167
# Init_Win_bytes_backward: 0.22348973792790205
# act_data_pkt_fwd: 0.0008561199482672101
# min_seg_size_forward: 0.1095414958246967
# Active Mean: 0.004612055234037323
# Active Std: 0.0020574902555636765
# Active Max: 0.1566136010961885
# Active Min: 0.0022440579059764204
# Idle Mean: 0.0015260175078438145
# Idle Std: 0.000404550794429747
# Idle Max: 0.0004890647085725075
# Idle Min: 0.00173937910339928
#
# Feature Importance:
# Flow Duration: 0.01132383034721786
# Total Fwd Packets: 0.0011521823672836083
# Total Backward Packets: 0.0019779671502607754
# Total Length of Fwd Packets: 0.0016112646140297648
# Total Length of Bwd Packets: 0.009010859695911984
# Fwd Packet Length Max: 0.002033049354396505
# Fwd Packet Length Min: 0.0003684524676731357
# Fwd Packet Length Mean: 0.0015270667431286893
# Fwd Packet Length Std: 0.0056164499819998034
# Bwd Packet Length Max: 0.004269404296302407
# Bwd Packet Length Min: 0.03018274987089826
# Bwd Packet Length Mean: 0.012207280452746294
# Bwd Packet Length Std: 0.005430136947616531
# Flow Bytes/s: 0.0
# Flow Packets/s: 0.0
# Flow IAT Mean: 0.011106813728044607
# Flow IAT Std: 0.013443212118905139
# Flow IAT Max: 0.0967018718021265
# Flow IAT Min: 0.006805400850273441
# Fwd IAT Total: 0.010839855765948989
# Fwd IAT Mean: 0.05029395748226391
# Fwd IAT Std: 0.009289970377367293
# Fwd IAT Max: 0.009597369595897564
# Fwd IAT Min: 0.009312261931262195
# Bwd IAT Total: 0.003553515865174036
# Bwd IAT Mean: 0.0020650259511732854
# Bwd IAT Std: 0.0033449958814171844
# Bwd IAT Max: 0.003512203554074769
# Bwd IAT Min: 0.003897159239753005
# Fwd PSH Flags: 0.000375356817838512
# Bwd PSH Flags: 0.0
# Fwd URG Flags: 0.0
# Bwd URG Flags: 0.0
# Fwd Header Length: 0.0
# Bwd Header Length: 0.001239284299743687
# Fwd Packets/s: 0.010854735787087056
# Bwd Packets/s: 0.0321863885727387
# Min Packet Length: 0.0006589046532859717
# Max Packet Length: 0.0014180876019027878
# Packet Length Mean: 0.007289536912861124
# Packet Length Std: 0.009820176714952713
# Packet Length Variance: 0.0027178220087030565
# FIN Flag Count: 0.0
# SYN Flag Count: 8.39608218522579e-05
# RST Flag Count: 0.0
# PSH Flag Count: 0.001702531695981214
# ACK Flag Count: 0.0
# URG Flag Count: 0.0025963829132588565
# CWE Flag Count: 0.0
# ECE Flag Count: 0.0
# Down/Up Ratio: 0.0005991207912393044
# Average Packet Size: 0.002713636573010246
# Avg Fwd Segment Size: 0.0008280032180530753
# Avg Bwd Segment Size: 0.017656582801772656
# Fwd Header Length.1: 0.00037294367182373866
# Fwd Avg Bytes/Bulk: 0.0
# Fwd Avg Packets/Bulk: 0.0
# Fwd Avg Bulk Rate: 0.0
# Bwd Avg Bytes/Bulk: 0.0
# Bwd Avg Packets/Bulk: 0.0
# Bwd Avg Bulk Rate: 0.0
# Subflow Fwd Packets: 0.010513948968739289
# Subflow Fwd Bytes: 0.0016090922561302183
# Subflow Bwd Packets: 0.00040782707674507
# Subflow Bwd Bytes: 0.0010174479003631227
# Init_Win_bytes_forward: 0.04508426516064703
# Init_Win_bytes_backward: 0.24803187795652076
# act_data_pkt_fwd: 0.000203913538372535
# min_seg_size_forward: 0.11139193493367681
# Active Mean: 0.0004497046221991458
# Active Std: 0.000937316852855266
# Active Max: 0.15945733254562086
# Active Min: 0.001376303530662041
# Idle Mean: 0.0010579318457884632
# Idle Std: 0.0028163571462215746
# Idle Max: 0.0006881042634560778
# Idle Min: 0.0013688771127492096
#
# Average Accuracy of Ensemble: 0.9068721901091843
# Average Precision of Ensemble: 0.915185278123459
# Average Recall of Ensemble: 0.9068721901091843
# Average F1-score of Ensemble: 0.9093092904645456
# Average Robustness Accuracy: 0.154
